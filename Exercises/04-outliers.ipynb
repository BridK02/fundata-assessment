# %% [markdown]
# # Outliers Assigments
#
# ***

# %%
# Numerical arrays.
import numpy as np

# Plotting.
import matplotlib.pyplot as plt

# Statistics.
import scipy.stats as ss

#import Pandas
import pandas as pd
from IPython.display import display

# %% [markdown]
# ***
#
# ### Exercise 1
#
#
# Create box plots on a single set of axes for all five experiments in the morley data set.
#
# ***

# %%
# Read in the morley data.
data = np.genfromtxt('data/morley.csv', skip_header=1, delimiter=',', deletechars='"')

# Remove the first column.
data = data[:,1:]

#df = pd.read_csv('data/morley.csv')
#df.describe

# %%
# Select the data for the first experiment.
exper_1 = data[:20, 2]

exper_1
# Out:
# array([ 850.,  740.,  900., 1070.,  930.,  850.,  950.,  980.,  980.,
#         880., 1000.,  980.,  930.,  650.,  760.,  810., 1000., 1000.,
#         960.,  960.])

# %%
# Select the data for the second experiment.
exper_2 = data[20:40, 2]

exper_2
# Out:
# array([960., 940., 960., 940., 880., 800., 850., 880., 900., 840., 830.,
#        790., 810., 880., 880., 830., 800., 790., 760., 800.])

# %%
# Select the data for the second experiment.
exper_3 = data[40:60, 2]

exper_3
# Out:
# array([880., 880., 880., 860., 720., 720., 620., 860., 970., 950., 880.,
#        910., 850., 870., 840., 840., 850., 840., 840., 840.])

# %%
# Select the data for the second experiment.
exper_4 = data[60:80, 2]

exper_4
# Out:
# array([890., 810., 810., 820., 800., 770., 760., 740., 750., 760., 910.,
#        920., 890., 860., 880., 720., 840., 850., 850., 780.])

# %%
# Select the data for the second experiment.
exper_5 = data[80:100, 2]

exper_5
# Out:
# array([890., 840., 780., 810., 760., 810., 790., 810., 820., 850., 870.,
#        870., 810., 740., 810., 940., 950., 800., 810., 870.])

# %%
# Create a box plot.
plt.boxplot(np.array([exper_1, exper_2, exper_3, exper_4, exper_5],).T);

# %% [markdown]
# ***
#
# ### Exercise 2
#
#
# Create box plots for all of the numercial variables in Fisher's Iris Data Set.
#
# ***

# %%
import pandas as pd
import seaborn as sns #data visualisation library
import matplotlib.pyplot as plt # allow me to plot the data
import numpy as np
csv_file = "data/iris.csv"
txt_file = "data/Iris.txt"
text_list = []

with open(csv_file, "r") as my_input_file:
    for line in my_input_file:
        line = line.split(",", 5) 
        text_list.append(" ".join(line))

with open(txt_file, "w") as my_output_file:
    my_output_file.write("#1\n")
    my_output_file.write("double({},{})\n".format(len(text_list), 5))
    for line in text_list:
        my_output_file.write("  " + line)
    print('File Successfully written.')
# Out:
# File Successfully written.

# %%
with open("summary.txt", "a") as f: 
#creating a dataframe of the iris csv
    iris_df=pd.read_csv("data/iris.csv")
#testing how the iris_df looks
    print (iris_df.dtypes, file = f) #summary of the data types to see if anything the data needs to be cleaned up
#the iris_df.dtypes above shows that the class is of type objects
    iris_df.info(buf=f)#this info shows that there are no null values and that the data again the the length and width 
#values are numerical whereas the class value are categorical
    iris_df.describe()

# %% [markdown]
# ## A Data Set
#
# ***
#
# In the next cell I am going to generate a set of numbers.
#
# We will then plot and consider them.

# %%
#          9.52631579,  9.63157895,  9.73684211,  9.84210526,  9.94736842,
#         10.05263158, 10.15789474, 10.26315789, 10.36842105, 10.47368421,
#         10.57894737, 10.68421053, 10.78947368, 10.89473684, 11.        ]])

# %%
eg = (-1.0 * 5 + 2 * 3) # working out the algorithm using the array starting with three and ending with 5
eg
# Out:
# 1.0

# %%
# Create a corresponding series of y vectors.
#this algorithm multiplies each number in the above arrays by -1 then adds twice the starting number in each array
ys = np.array([-1.0 * xs[i] + 2 * i for i in range(len(xs))])
ys
# Out:
# array([[ 0.        , -0.10526316, -0.21052632, -0.31578947, -0.42105263,
#         -0.52631579, -0.63157895, -0.73684211, -0.84210526, -0.94736842,
#         -1.05263158, -1.15789474, -1.26315789, -1.36842105, -1.47368421,
#         -1.57894737, -1.68421053, -1.78947368, -1.89473684, -2.        ],
#        [ 1.        ,  0.89473684,  0.78947368,  0.68421053,  0.57894737,
#          0.47368421,  0.36842105,  0.26315789,  0.15789474,  0.05263158,
#         -0.05263158, -0.15789474, -0.26315789, -0.36842105, -0.47368421,
#         -0.57894737, -0.68421053, -0.78947368, -0.89473684, -1.        ],
#        [ 2.        ,  1.89473684,  1.78947368,  1.68421053,  1.57894737,
#          1.47368421,  1.36842105,  1.26315789,  1.15789474,  1.05263158,
#          0.94736842,  0.84210526,  0.73684211,  0.63157895,  0.52631579,
#          0.42105263,  0.31578947,  0.21052632,  0.10526316,  0.        ],
#        [ 3.        ,  2.89473684,  2.78947368,  2.68421053,  2.57894737,
#          2.47368421,  2.36842105,  2.26315789,  2.15789474,  2.05263158,
#          1.94736842,  1.84210526,  1.73684211,  1.63157895,  1.52631579,
#          1.42105263,  1.31578947,  1.21052632,  1.10526316,  1.        ],
#        [ 4.        ,  3.89473684,  3.78947368,  3.68421053,  3.57894737,
#          3.47368421,  3.36842105,  3.26315789,  3.15789474,  3.05263158,
#          2.94736842,  2.84210526,  2.73684211,  2.63157895,  2.52631579,
#          2.42105263,  2.31578947,  2.21052632,  2.10526316,  2.        ],
#        [ 5.        ,  4.89473684,  4.78947368,  4.68421053,  4.57894737,
#          4.47368421,  4.36842105,  4.26315789,  4.15789474,  4.05263158,
#          3.94736842,  3.84210526,  3.73684211,  3.63157895,  3.52631579,
#          3.42105263,  3.31578947,  3.21052632,  3.10526316,  3.        ],
#        [ 6.        ,  5.89473684,  5.78947368,  5.68421053,  5.57894737,
#          5.47368421,  5.36842105,  5.26315789,  5.15789474,  5.05263158,
#          4.94736842,  4.84210526,  4.73684211,  4.63157895,  4.52631579,
#          4.42105263,  4.31578947,  4.21052632,  4.10526316,  4.        ],
#        [ 7.        ,  6.89473684,  6.78947368,  6.68421053,  6.57894737,
#          6.47368421,  6.36842105,  6.26315789,  6.15789474,  6.05263158,
#          5.94736842,  5.84210526,  5.73684211,  5.63157895,  5.52631579,
#          5.42105263,  5.31578947,  5.21052632,  5.10526316,  5.        ],
#        [ 8.        ,  7.89473684,  7.78947368,  7.68421053,  7.57894737,
#          7.47368421,  7.36842105,  7.26315789,  7.15789474,  7.05263158,
#          6.94736842,  6.84210526,  6.73684211,  6.63157895,  6.52631579,
#          6.42105263,  6.31578947,  6.21052632,  6.10526316,  6.        ],
#        [ 9.        ,  8.89473684,  8.78947368,  8.68421053,  8.57894737,
#          8.47368421,  8.36842105,  8.26315789,  8.15789474,  8.05263158,
#          7.94736842,  7.84210526,  7.73684211,  7.63157895,  7.52631579,
#          7.42105263,  7.31578947,  7.21052632,  7.10526316,  7.        ]])

# %%
# Add some noise.
ys = ys + np.random.normal(0.0, 1.0, ys.shape)
plt.plot (ys)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\bridc\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Create global list of x and y values.
x = xs.flatten()
y = ys.flatten()
plt.plot (y)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\bridc\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.plot (x)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\bridc\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Plot.
plt.plot(x, y, '.');

# %% [markdown]
# ## Best Fit Line
#
# ***
#
# In the next cell I am going to generate a set of numbers.
#
# We will then plot and consider them.

# %%
# Best fit line slope and y intercept.
m, c = np.polyfit(x, y, 1)

# %%
# Create a steadily increasing x range for plotting.
xbestfit = np.linspace(x.min(), x.max(), 1000)
# Create corresponding y values form best fit line.
ybestfit = m * xbestfit + c

# %%
# Plot points.
plt.plot(x, y, '.')

# Plot line.
plt.plot(xbestfit, ybestfit);

# %% [markdown]
# ## Colours
#
# ***

# %%
# Plot the same points, but now with a different colour for each range.
for i in range(len(xs)):
    plt.plot(xs[i], ys[i],'.' )

# %%
# Same plot but with best fit lines for each category.
for i in range(len(xs)):
    # Plot this category.
    plt.plot(xs[i], ys[i], '.')
    # Fit line to category.
    m, c = np.polyfit(xs[i], ys[i], 1)
    # Create steadily increasing x range for plot.
    xbestfit = np.linspace(xs[i].min(), xs[i].max(), 50)
    # Corresponding y values based on best fit line.
    ybestfit = m * xbestfit + c
    # Plot best fit line for category.
    plt.plot(xbestfit, ybestfit, color='lightgrey');

# %% [markdown]
# ***
#
# ### Exercise 3
#
#
# Adapt the above code and plots so that the overall plot is inversely propertional and the individual groups are directly proportional.
#
# ***

# %%
#https://www.educba.com/numpy-inverse/
#https://www.geeksforgeeks.org/how-to-inverse-a-matrix-using-numpy/
#https://www.geeksforgeeks.org/numpy-invert-in-python/
xs = np.array([np.linspace(i, i + 2.0, 20) for i in range(10)])

# Create a corresponding series of y vectors.
ys = np.array([-1.0 * xs[i] + 2 * i for i in range(len(xs))])

# Add some noise.
ys = ys + np.random.normal(0.0, 1.0, ys.shape)


# Same plot but with best fit lines for each category.
for i in range(len(xs)):
    # Plot this category multiplying by -1 to given the inverse
    plt.plot(xs[i], ys[i]*-1, '.')
    # Fit line to category.
    m, c = np.polyfit(xs[i], ys[i], 1)
    # Create steadily increasing x range for plot.
    xbestfit = np.linspace(xs[i].min(), xs[i].max(), 50)
    # Corresponding y values based on best fit line.
    ybestfit = m * xbestfit + c
    # Plot best fit line for category.
    plt.plot(xbestfit, ybestfit*-1, color='lightgrey');

# %% [markdown]
# ***
#
# ## End
